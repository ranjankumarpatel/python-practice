# %%
host thinktalentindia.com
# Out:
# thinktalentindia.com has address 69.89.14.158
# thinktalentindia.com mail is handled by 30 mx-indiabiz.mail.gm0.yahoodns.net.

# %%
whois thinktalentindia.com
# Out:
# Whois Server Version 2.0
#
# Domain names in the .com and .net domains can now be registered
# with many different competing registrars. Go to http://www.internic.net
# for detailed information.
#
#    Domain Name: THINKTALENTINDIA.COM
#    Registrar: NET 4 INDIA LIMITED
#    Sponsoring Registrar IANA ID: 1007
#    Whois Server: whois.net4domains.com
#    Referral URL: http://www.net4.in
#    Name Server: NS11.EAPPS.COM
#    Name Server: NS12.EAPPS.COM
#    Name Server: NS13.EAPPS.COM
#    Name Server: NS14.EAPPS.COM
#    Status: ok https://icann.org/epp#ok
#    Updated Date: 09-dec-2016
#    Creation Date: 08-dec-2009
#    Expiration Date: 08-dec-2017
#
# >>> Last update of whois database: Sun, 23 Apr 2017 07:21:06 GMT <<<
#
# For more information on Whois status codes, please visit https://icann.org/epp
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# ...

# %%
whois -h whois.arin.net 69.89.14.3
# Out:
# #
# # ARIN WHOIS data and services are subject to the Terms of Use
# # available at: https://www.arin.net/whois_tou.html
# #
# # If you see inaccuracies in the results, please report at
# # https://www.arin.net/public/whoisinaccuracy/index.xhtml
# #
#
#
# #
# # The following results may also be obtained via:
# # https://whois.arin.net/rest/nets;q=69.89.14.3?showDetails=true&showARIN=false&showNonArinTopLevelNet=false&ext=netref2
# #
#
# NetRange:       69.89.0.0 - 69.89.15.255
# CIDR:           69.89.0.0/20
# NetName:        SUBNET-2
# NetHandle:      NET-69-89-0-0-1
# Parent:         NET69 (NET-69-0-0-0-0)
# NetType:        Direct Assignment
# OriginAS:
# Organization:   Strategic Systems Consulting (SSC-145)
# RegDate:        2006-10-17
# Updated:        2012-03-02
# Comment:        Statically Assigned to Customers
# Ref:            https://whois.arin.net/rest/net/NET-69-89-0-0-1
#
#
# OrgName:        Strategic Systems Consulting
# OrgId:          SSC-145
# ...

# %%
dig mx thinktalentindia.com
# Out:
# ; <<>> DiG 9.10.3-P4-Ubuntu <<>> mx thinktalentindia.com
# ;; global options: +cmd
# ;; Got answer:
# ;; ->>HEADER<<- opcode: QUERY, status: NOERROR, id: 49172
# ;; flags: qr rd ra; QUERY: 1, ANSWER: 1, AUTHORITY: 0, ADDITIONAL: 1
#
# ;; OPT PSEUDOSECTION:
# ; EDNS: version: 0, flags:; udp: 4000
# ;; QUESTION SECTION:
# ;thinktalentindia.com.		IN	MX
#
# ;; ANSWER SECTION:
# thinktalentindia.com.	3600	IN	MX	30 mx-indiabiz.mail.gm0.yahoodns.net.
#
# ;; Query time: 1507 msec
# ;; SERVER: 127.0.1.1#53(127.0.1.1)
# ;; WHEN: Sun Apr 23 12:48:40 IST 2017
# ;; MSG SIZE  rcvd: 98
