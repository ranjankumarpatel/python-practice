# %%
import pandas as pd

# %%
dir = "D:/jupyter/challenges/products-shelves-tagging-dataset"
dir+"/test.tsv"
# Out:
# 'D:/jupyter/challenges/products-shelves-tagging-dataset/test.tsv'

# %%
test = pd.read_table(dir+"/test.tsv")
train = pd.read_table(dir+"/train.tsv")

# %%
train.head()
# Out:
#    item_id        Seller Actors Actual Color  Artist ID Aspect Ratio Color  \
# 0        0  Circuit City    NaN   Multicolor        NaN          NaN   NaN
# 1        1           NaN    NaN        Black        NaN          NaN   NaN
# 2        2           NaN    NaN          NaN        NaN          NaN   NaN
# 3        3        Pcrush    NaN   Multicolor        NaN          NaN   NaN
# 4        4   Walmart.com    NaN        Black        NaN          NaN   NaN
#
#    Genre ID  ISBN Item Class ID         ...          \
# 0       NaN   NaN             1         ...
# 1       NaN   NaN             1         ...
# 2       NaN   NaN             1         ...
# 3       NaN   NaN            19         ...
# 4       NaN   NaN            19         ...
#
#                                         Product Name  \
# 0  Cyberpower Metered ATS PDU 200-240V 20A 1U 10-...
# 1  Peerless SmartMount SF650P Universal Flat Wall...
# 2  DAYTON 31EH66 Control Transformer Fused,4.02H ...
# ...

# %%
train.tag.str.split(",")
# Out:
# 0                               [[4483]]
# 1                             [[581514]]
# 2                               [[4483]]
# 3                               [[4537]]
# 4                  [[1229817,  1229821]]
# 5                               [[4537]]
# 6                               [[4483]]
# 7                               [[4483]]
# 8                            [[3304195]]
# 9                            [[1180168]]
# 10                  [[1229821,  447913]]
# 11                            [[522484]]
# 12                           [[1070524]]
# 13                           [[1229817]]
# 14                           [[1229821]]
# 15                             [[95987]]
# 16                              [[4483]]
# 17        [[1229821,  1229817,  447913]]
# 18                            [[127175]]
# 19                              [[4483]]
# 20                            [[529295]]
# 21                            [[127175]]
# 22                             [[95987]]
# ...
